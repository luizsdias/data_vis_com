# %% [markdown]
# <a href="https://colab.research.google.com/github/luizsdias/data_vis_com/blob/CA1/Data_Visualization_CA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Visualization CA1
# ##### David Silva | Student number: 0000000
# ##### Luiz Dias | Student number: 2018429

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://corgis-edu.github.io/corgis/datasets/csv/cars/cars.csv")

# %%
df.shape
# Out:
# (5076, 18)

# %%
df.head()
# Out:
#    Dimensions.Height  ...  Engine Information.Engine Statistics.Torque
# 0                140  ...                                          236
# 1                140  ...                                          207
# 2                140  ...                                          207
# 3                140  ...                                          207
# 4                140  ...                                          207
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dimensions.Height                                5076 non-null   int64
#  1   Dimensions.Length                                5076 non-null   int64
#  2   Dimensions.Width                                 5076 non-null   int64
#  3   Engine Information.Driveline                     5076 non-null   object
#  4   Engine Information.Engine Type                   5076 non-null   object
#  5   Engine Information.Hybrid                        5076 non-null   bool
#  6   Engine Information.Number of Forward Gears       5076 non-null   int64
#  7   Engine Information.Transmission                  5076 non-null   object
#  8   Fuel Information.City mpg                        5076 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Dimensions.Height  ...  Engine Information.Engine Statistics.Torque
# count        5076.000000  ...                                  5076.000000
# mean          145.632191  ...                                   272.707250
# std            62.125026  ...                                   100.123328
# min             1.000000  ...                                    98.000000
# 25%           104.000000  ...                                   187.000000
# 50%           152.000000  ...                                   260.000000
# 75%           193.000000  ...                                   335.000000
# max           255.000000  ...                                   774.000000
#
# [8 rows x 9 columns]

# %%
pd.isna(df).sum()
# Out:
# Dimensions.Height                                  0
# Dimensions.Length                                  0
# Dimensions.Width                                   0
# Engine Information.Driveline                       0
# Engine Information.Engine Type                     0
# Engine Information.Hybrid                          0
# Engine Information.Number of Forward Gears         0
# Engine Information.Transmission                    0
# Fuel Information.City mpg                          0
# Fuel Information.Fuel Type                         0
# Fuel Information.Highway mpg                       0
# Identification.Classification                      0
# Identification.ID                                  0
# Identification.Make                                0
# Identification.Model Year                          0
# Identification.Year                                0
# Engine Information.Engine Statistics.Horsepower    0
# Engine Information.Engine Statistics.Torque        0
# ...

# %%
df_numeric = df.iloc[:, [*range(0,2),6,8,10,*range(15,17)]]
df_numeric.head()
# Out:
#    Dimensions.Height  ...  Engine Information.Engine Statistics.Horsepower
# 0                140  ...                                              250
# 1                140  ...                                              200
# 2                140  ...                                              200
# 3                140  ...                                              200
# 4                140  ...                                              200
#
# [5 rows x 7 columns]

# %%
(df_numeric.values < 0).any()
# Out:
# False

# %%
df.rename(columns={'Identification.Make': 'Make'}, inplace = True)

# %%
df.rename(columns={'Fuel Information.Fuel Type': 'Fuel_Type'}, inplace = True)

# %%
df_audi = df[df.Make == 'Audi']

# %%
df_audi
# Out:
#       Dimensions.Height  ...  Engine Information.Engine Statistics.Torque
# 0                   140  ...                                          236
# 1                   140  ...                                          207
# 2                   140  ...                                          207
# 3                   140  ...                                          207
# 4                   140  ...                                          207
# ...                 ...  ...                                          ...
# 4501                103  ...                                          258
# 4502                191  ...                                          328
# 4503                180  ...                                          328
# 4504                191  ...                                          463
# 4505                 62  ...                                          343
#
# [87 rows x 18 columns]

# %%
plt.figure(figsize=(10,15))
plt.xlabel('Fuel Type')
plt.ylabel('Make')
plt.title('Models by fuel type', fontsize = 15)
plt.barh(df.Make,df.Fuel_Type, color= 'purple')
#plt.xticks(rotation=45)
# Out:
# <BarContainer object of 5076 artists>
